# %% [markdown]
# # Project

# %% [markdown]
# # Final Project - Analyzing Sales Data
#
# **Date**: 17 August 2022
#
# **Author**: Ginna Phanvimolchai
#
# **Course**: `Pandas Foundation`

# %%
# import data
import pandas as pd
df = pd.read_csv("sample-store.csv")

# %%
# preview top 5 rows
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# shape of dataframe
df.shape
# Out:
# (9994, 21)

# %%
# see data frame information using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %% [markdown]
# We can use `pd.to_datetime()` function to convert columns 'Order Date' and 'Ship Date' to datetime.

# %%
# example of pd.to_datetime() function
pd.to_datetime(df['Order Date'],format='%m/%d/%Y')

# %%
# TODO - convert order date and ship date to datetime in the original dataframe
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO - count nan in postal code column
df["Postal Code"].isna().sum()
# Out:
# 11

# %%
# TODO - filter rows with missing values
df[df["Postal Code"].isna()]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2234</th>
# ...

# %%
# TODO - Explore this dataset on your owns, ask your own questions

#which region is the best seller and what category is it?
rgct = df.groupby(["Region","Category"])["Sales"].sum().reset_index()
rgct
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Region</th>
#       <th>Category</th>
#       <th>Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Central</td>
#       <td>Furniture</td>
#       <td>163797.1638</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Central</td>
#       <td>Office Supplies</td>
#       <td>167026.4150</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Central</td>
#       <td>Technology</td>
#       <td>170416.3120</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>East</td>
#       <td>Furniture</td>
#       <td>208291.2040</td>
#     </tr>
#     <tr>
# ...

# %%
#which sub-category is the bestseller and most profit?
subcat = df.groupby("Sub-Category")[["Sales","Profit"]].sum().sort_values("Profit", ascending=False)
subcat
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sales</th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Sub-Category</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Copiers</th>
#       <td>149528.0300</td>
#       <td>55617.8249</td>
#     </tr>
#     <tr>
#       <th>Phones</th>
#       <td>330007.0540</td>
#       <td>44515.7306</td>
#     </tr>
#     <tr>
#       <th>Accessories</th>
#       <td>167380.3180</td>
#       <td>41936.6357</td>
#     </tr>
#     <tr>
#       <th>Paper</th>
#       <td>78479.2060</td>
#       <td>34053.5693</td>
#     </tr>
#     <tr>
#       <th>Binders</th>
# ...

# %%
#most frequency customer
mf = df["Customer ID"].value_counts()
mf

# %%
#most spending customer
ct = df.groupby("Customer ID")["Sales"].sum().sort_values(ascending=False).round(decimals=2)
ct

# %% [markdown]
# ## Data Analysis Part
#
# Answer 10 below questions to get credit from this course. Write `pandas` code to find answers.

# %%
# TODO 01 - how many columns, rows in this dataset
df.shape
# Out:
# (9994, 21)

# %%
# TODO 02 - is there any missing values?, if there is, which colunm? how many nan values?
#Yes columns "Postal Code" is the one has missing value 11 row.
df.isna().sum().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64>

# %%
# TODO 03 - your friend ask for `California` data, filter it and export csv for him
##filter data to "california"
result = df.query('State == "California"')
result.to_csv("Californai.csv")

result
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
# ...

# %%
# TODO 04 - your friend ask for all order data in `California` and `Texas` in 2017 (look at Order Date), send him csv file
##change data date
df["Order Date"] = pd.to_datetime(df['Order Date'])
##filter state data
stdata = df.query("State == ['California','Texas']")
##filter date only in 2017
cal_tex_2017 = stdata[(stdata["Order Date"] >= '2017-01-01') & (stdata["Order Date"] <= "2017-12-31")]

cal_tex_2017.to_csv("cal-tex-2017.csv")

cal_tex_2017
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
# ...

# %%
# TODO 05 - how much total sales, average sales, and standard deviation of sales your company make in 2017
##change data date
df["Order Date"] = pd.to_datetime(df['Order Date'])
##filter date only in 2017
df17 = df[(df["Order Date"] >= '2017-01-01') & (df["Order Date"] <= "2017-12-31")]
##result of sum mean std
df17["Sales"].agg(["sum","mean","std"]).round(decimals=2)

# %%
# TODO 06 - which Segment has the highest profit in 2018
##filter date only in 2018
df18 = df[(df["Order Date"] >= '2018-01-01') & (df["Order Date"] <= "2018-12-31")]

#group segment and sum for highest amount
df.groupby(["Segment"])["Profit"].sum().sort_values(ascending=False).round(decimals=2)
#round decimal for 2 for real life
##the highest profit in 2018 is Consumer

# %%
# TODO 07 - which top 5 States have the least total sales between 15 April 2019 - 31 December 2019
#select date between 15 April 2019 - 31 December 2019

df19 = df[(df["Order Date"] >= '2019-04-15') & (df["Order Date"] <= "2019-12-31")]


df19.groupby(["State"])["Sales"].sum().sort_values().head()

#top 5 States least total sale
#1.New Hampshire
#2.New Mexico
#3.District of Columbia
#4.Louisiana
#5.South Carolina

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#       <th>month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO 08 - what is the proportion of total sales (%) in West + Central in 2019 e.g. 25% 
#filter date
pp19 = df[(df["Order Date"] >= '2019-01-01') & (df["Order Date"] <= "2019-12-31")]
##filter only West and central and sum
# total is 334909.5525
sum_WC_sale = pp19.query("Region == ['West','Central']")["Sales"].sum()
#sum Total Sales = 609205.598
sum_sale = pp19["Sales"].sum()


pps = (sum_WC_sale/sum_sale)*100
pps
# proportion of total sale in West+Central = 54.97%
# Out:
# 54.97479891837763

# %%
# TODO 09 - find top 10 popular products in terms of number of orders vs. total sales during 2019-2020
#filter date during 2019-2020
df20 = df[(df["Order Date"] >= '2019-01-01') & (df["Order Date"] <= "2020-12-31")]

#select top 10 by sort product and show price to compare
df20 =  df20.groupby("Product Name")["Sales"].agg(["count","sum"])\
        .sort_values("count",ascending=False)\
        .head(10).round(decimals=2)

df20
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>sum</th>
#     </tr>
#     <tr>
#       <th>Product Name</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Easy-staple paper</th>
#       <td>27</td>
#       <td>1481.73</td>
#     </tr>
#     <tr>
#       <th>Staples</th>
#       <td>24</td>
#       <td>462.07</td>
#     </tr>
#     <tr>
#       <th>Staple envelope</th>
#       <td>22</td>
#       <td>644.94</td>
#     </tr>
#     <tr>
#       <th>Staples in misc. colors</th>
#       <td>13</td>
#       <td>357.16</td>
#     </tr>
#     <tr>
#       <th>Staple remover</th>
# ...

# %%
# TODO 10 - plot at least 2 plots, any plot you think interesting :)
#which Region is the most sale in 2019
rgs = df[(df["Order Date"] >= '2019-01-01') & (df["Order Date"] <= "2019-12-31")]
rgs = rgs.groupby(["Region"])["Sales"].sum()
rgs.plot(kind="bar",color="salmon");

# %%
#sale trend in 2018
df["month"] = pd.to_datetime(df['Order Date']).dt.month
df18 = df[(df["Order Date"] >= '2018-01-01') & (df["Order Date"] <= '2018-12-31')]
ss18 = df18.groupby(["month"])["Sales"].sum()

ss18.plot(kind="line");

# %%
## line chart for total sale between 2018 and 2019
#sale tread in 2019
df19 = df[(df["Order Date"] >= '2019-01-01') & (df["Order Date"] <= "2019-12-31")]
ss19 = df19.groupby(["month"])["Sales"].sum()

#create new dataframe
gs18 = pd.DataFrame(ss18)
#change columns name
gs18.columns = ["sale 2018"]

#create new dataframe        
gs19 = pd.DataFrame(ss19)
#change columns name
gs19.columns = ["sale 2019"]
#merge dataframe
gs = pd.merge(gs18,gs19, on="month")

gs.plot(kind="line");

# %%
# TODO Bonus - use np.where() to create new column in dataframe to help you answer your own questions
#create new columns to tell us word about amount of sale
import numpy as np
df["Big Amount"] = np.where(df["Sales"]>= 1000,"Big Amount",False)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#       <th>month</th>
#       <th>Big Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...
